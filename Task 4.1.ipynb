# %%
import cv2
import numpy

img=numpy.zeros((800,1020,3),numpy.uint8)

### 1
radius=100
axes = (200,140)
angle=0;
startAngle=-47;
endAngle=-133;
center=(450,300)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 2
radius=100
axes = (200,140)
angle=0;
startAngle=-103;
endAngle=-135;
center=(450,335)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)


radius=10
axes = (5,10)
angle=105;
startAngle=0;
endAngle=360;
center=(540,230)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)





### 3
radius=100
axes = (200,140)
angle=0;
startAngle=-45;
endAngle=-77;
center=(450,335)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)


radius=10
axes = (5,10)
angle=75;
startAngle=0;
endAngle=360;
center=(360,230)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)



### 4
radius=10
axes = (120,140)
angle=0;
startAngle=-70;
endAngle=-110;
center=(450,360)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 5
radius=10
axes = (400,140)
angle=-95;
startAngle=-83;
endAngle=-102;
center=(546,200)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (400,140)
angle=-95;
startAngle=-88;
endAngle=-102;
center=(546,200)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)



### 6
radius=10
axes = (400,140)
angle=95;
startAngle=-78;
endAngle=-97;
center=(355,200)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (400,140)
angle=95;
startAngle=-78;
endAngle=-92;
center=(355,200)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)



### 7
radius=10
axes = (120,140)
angle=-110;
startAngle=-71;
endAngle=-87;
center=(490,170)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 8
radius=10
axes = (120,140)
angle=97;
startAngle=-79;
endAngle=-94;
center=(410,170)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 9
radius=10
axes = (120,140)
angle=180;
startAngle=-75;
endAngle=-106;
center=(450,160)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)






### 11
radius=10
axes = (800,140)
angle=82;
startAngle=-91;
endAngle=-100;
center=(190,392)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 3)

### 12
radius=10
axes = (800,140)
angle=280;
startAngle=-92;
endAngle=-101;
center=(730,233)
color=(16,217,224)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 3)

### 13
radius=10
axes = (400,140)
angle=-81;
startAngle=-83;
endAngle=-110;
center=(442,267)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 14
radius=10
axes = (400,140)
angle=83;
startAngle=-70;
endAngle=-97;
center=(455,263)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 15
radius=10
axes = (400,140)
angle=-95;
startAngle=-83;
endAngle=-97;
center=(448,280)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 16
radius=10
axes = (400,140)
angle=94;
startAngle=-82;
endAngle=-97;
center=(448,280)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 17
radius=10
axes = (120,140)
angle=-76;
startAngle=-71;
endAngle=-84;
center=(445,430)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 6)

### 18
radius=10
axes = (120,140)
angle=61;
startAngle=-81;
endAngle=-94;
center=(450,438)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 6)


### 19
radius=10
axes = (160,140)
angle=-84;
startAngle=-71;
endAngle=-82;
center=(440,405)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 20
radius=10
axes = (160,140)
angle=73;
startAngle=-84;
endAngle=-94;
center=(453,398)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)


### 21

### 22


### 23
radius=10
axes = (120,800)
angle=134;
startAngle=-64;
endAngle=-97;
center=(-167,-154)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 5)

radius=10
axes = (120,500)
angle=255;
startAngle=-88;
endAngle=-95;
center=(790,243)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 6)


### 24
radius=10
axes = (120,800)
angle=230;
startAngle=-85;
endAngle=-116;
center=(1099,-113)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 5)

radius=10
axes = (120,500)
angle=129;
startAngle=-85;
endAngle=-93;
center=(199,68)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 6)



### 10
radius=100
axes = (200,140)
angle=180;
startAngle=-52;
endAngle=-126;
center=(450,250)
color=(20,180,210)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 12)




### 25
radius=10
axes = (120,200)
angle=-80;
startAngle=-89;
endAngle=-125;
center=(500,405)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 26
radius=10
axes = (120,200)
angle=80;
startAngle=-56;
endAngle=-92;
center=(396,415)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 27
radius=10
axes = (130,60)
angle=65;
startAngle=-50;
endAngle=-140;
center=(333,550)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (130,60)
angle=65;
startAngle=-66;
endAngle=-140;
center=(333,550)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 4)
######
###
radius=10
axes = (10,50)
angle=26;
startAngle=120;
endAngle=250;
center=(553,500)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, -1)

###
radius=10
axes = (120,0)
angle=98;
startAngle=-58;
endAngle=-87;
center=(344,480)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,0)
angle=82;
startAngle=-58;
endAngle=-87;
center=(553,480)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (2,8)
angle=10;
startAngle=0;
endAngle=360;
center=(332,508)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, -1)

radius=10
axes = (2,8)
angle=170;
startAngle=0;
endAngle=360;
center=(565,508)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, -1)


######

### 28
radius=10
axes = (120,60)
angle=-55;
startAngle=-60;
endAngle=-150;
center=(581,530)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,60)
angle=-55;
startAngle=-60;
endAngle=-150;
center=(581,530)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)
radius=10
axes = (120,60)
angle=-55;
startAngle=-60;
endAngle=-134;
center=(581,530)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 4)



######
###
radius=10
axes = (10,50)
angle=154;
startAngle=120;
endAngle=250;
center=(348,498)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, -1)

######


### 29
radius=10
axes = (120,0)
angle=180;
startAngle=-63;
endAngle=-118;
center=(450,540)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 12)

# i
radius=10
axes = (120,0)
angle=180;
startAngle=-68;
endAngle=-77;
center=(450,576)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

# ii
radius=10
axes = (120,0)
angle=180;
startAngle=-105;
endAngle=-113;
center=(450,576)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

# iii
radius=10
axes = (120,0)
angle=180;
startAngle=-82;
endAngle=-100;
center=(450,567)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

# =
radius=10
axes = (120,0)
angle=43;
startAngle=-90;
endAngle=-97;
center=(480,577)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

# =
radius=10
axes = (120,0)
angle=133;
startAngle=-90;
endAngle=-97;
center=(423,577)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

#############
##
radius=10
axes = (120,0)
angle=150;
startAngle=-64;
endAngle=-77;
center=(425,564)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,0)
angle=63;
startAngle=-60;
endAngle=-80;
center=(352,538)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,0)
angle=105;
startAngle=-64;
endAngle=-72;
center=(375,507)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,0)
angle=120;
startAngle=-64;
endAngle=-74;
center=(408,510)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 8)

radius=10
axes = (120,0)
angle=50;
startAngle=-60;
endAngle=-70;
center=(343,512)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 8)


##
###
radius=10
axes = (120,0)
angle=210;
startAngle=-64;
endAngle=-77;
center=(545,603)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,0)
angle=117;
startAngle=-60;
endAngle=-80;
center=(550,538)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,0)
angle=75;
startAngle=-64;
endAngle=-72;
center=(526,507)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

radius=10
axes = (120,0)
angle=60;
startAngle=-64;
endAngle=-74;
center=(494,510)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 8)

radius=10
axes = (120,0)
angle=130;
startAngle=-60;
endAngle=-70;
center=(559,512)
color=(5,230,230)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 8)


#############

### 30
radius=10
axes = (19,60)
angle=0;
startAngle=95;
endAngle=250;
center=(300,375)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 31
radius=10
axes = (19,60)
angle=0;
startAngle=90;
endAngle=-74;
center=(596,375)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 32
radius=10
axes = (50,200)
angle=-24;
startAngle=160;
endAngle=240;
center=(384,530)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)

### 33
radius=10
axes = (50,200)
angle=23;
startAngle=-60;
endAngle=18;
center=(512,534)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 2)


### 
radius=10
axes = (80,17)
angle=180;
startAngle=0;
endAngle=180;
center=(450,610)
color=(0,0,255)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, -1)






cv2.imshow("hi", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy

img=numpy.zeros((800,1020,3), numpy.uint8)

##############
t = 0 # thickness
##############


radius=100
axes = (200,140)
angle=180;
startAngle=-52;
endAngle=-126;
center=(450,250)
color=(0,100,150)

cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, 10)
cv2.imshow("hi", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
